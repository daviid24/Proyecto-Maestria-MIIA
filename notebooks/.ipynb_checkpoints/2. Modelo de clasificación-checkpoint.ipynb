# %% [markdown]
# # Modelo de Clasificación para Predicción de Segmento RFM (Nike Colombia)
#
# En el notebook **“1. Modelo de clusterización RFM.ipynb”** se construyó la segmentación de clientes a partir del modelo K-means utilizando las variables **Recency, Frequency y Monetary discretizadas (RFM scores)**. Dicho modelo fue seleccionado por su coherencia con el comportamiento transaccional y su capacidad para identificar 7 segmentos accionables.
#
# En este notebook se desarrolla el **modelo de clasificación**, cuyo objetivo es predecir el segmento RFM al que pertenecerá un **nuevo cliente**, utilizando únicamente la información disponible en su **primera compra**.
#
# ---
#
# ## Variables utilizadas para predecir el segmento
#
# A partir del análisis exploratorio (EDA), se identificaron cuatro variables categóricas con suficiente señal explicativa:
#
# - **BU_first** (unidad de negocio del primer producto comprado)
# - **Categoria_first** (categoría deportiva del producto inicial)
# - **first_disc_group** (tipo de descuento aplicado en la primera compra)
# - **Genero_first** (línea de género del producto)
#
# Además, se incluye la variable numérica:
#
# - **first_ticket** (valor pagado en la primera compra)
#
# Estas variables se transforman mediante **One-Hot Encoding** para preparar la matriz de entrenamiento. Se descartaron variables como **City_first** y **Familia/Silueta_first**, ya que su alta cardinalidad generaba un número excesivo de columnas dummy, aumentando complejidad y ruido sin mejorar el rendimiento del modelo.
#
# ---
#
# ## Modelos de clasificación evaluados
#
# Se entrenan y comparan tres algoritmos supervisados:
#
# 1. **Árbol de decisión**
# 2. **Red neuronal (MLP)**
# 3. **XGBoost**
#
# El desempeño se evalúa principalmente mediante **accuracy** y **F1-macro**, una métrica adecuada debido al desbalance natural entre segmentos.
#
# ---
#
# ## Incorporación de Conformal Prediction
#
# Una vez seleccionado el mejor modelo, se aplicará **Conformal Prediction** para obtener niveles de confianza y predicciones por conjunto. Esta técnica permite identificar casos ambiguos, evitar clasificaciones poco seguras y aportar mayor confiabilidad al sistema de segmentación anticipada aplicada al negocio.
#
# La incorporación de Conformal Prediction cobra especial relevancia en este caso, ya que el objetivo es predecir el **segmento RFM a partir únicamente de la primera compra de un cliente**. Dado que los segmentos RFM dependen de variables que evolucionan con el tiempo (como recency y frequency), es natural que el modelo de clasificación tienda a asignar inicialmente categorías específicas asociadas a perfiles de entrada, como “nuevos/ticket alto” o “nuevos/ticket bajo”. Sin embargo, estas categorías no necesariamente reflejan la evolución futura del cliente.
#
# **Mediante Conformal Prediction es posible obtener un conjunto de posibles segmentos en lugar de una única predicción puntual.** Esto permite capturar la incertidumbre inherente al proceso y reconocer, por ejemplo, que aunque el modelo base clasifique a un cliente como “nuevo/ticket alto”, su intervalo de confianza también puede incluir segmentos como “champion” o “leales recientes”, lo cual representa **rutas potenciales de evolución según su comportamiento futuro.** Esta capa adicional de interpretación mejora la capacidad del negocio para tomar decisiones más informadas y gestionar acciones tempranas sobre clientes con alto potencial.

# %%
# ======================================
# 1. Importación de librerías
# ======================================
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-v0_8-whitegrid")

# ======================================
# 2. Lectura de la base enriquecida (clusters + RFM)
# ======================================

# Nombre del archivo principal de datos
fname = "orders_enriched_with_RFM_KMdisc.csv"

# Ruta local (si el archivo está en la carpeta 'data/' del repo clonado)
local_path = os.path.join("data", fname)

# URL al archivo en GitHub (repositorio público)
raw_url = (
    "https://raw.githubusercontent.com/"
    "daviid24/Proyecto-Maestria-MIIA/main/data/"
    + fname
)

# Si el archivo existe localmente, se lee desde el disco
# En caso contrario, se descarga directamente desde GitHub
if os.path.exists(local_path):
    df = pd.read_csv(local_path, encoding="utf-8-sig")
else:
    df = pd.read_csv(raw_url, encoding="utf-8-sig")

# Vista previa de la base cargada
df.head()
# Out:
#   FechaSinHora             Order Client_Document            UF  \
# 0   2024-02-06  1408880501419-01      1010121222     Antioquia
# 1   2024-02-06  1408840501369-01        80122644  Bogotá, D.C.
# 2   2024-02-06  1408830501357-01      1047499286       Bolívar
# 3   2024-02-06  1408860501387-01        80096408  Cundinamarca
# 4   2024-02-06  1408810501345-01        91018601     Santander
#
#                   City RealDiscount Discounts_Names      Shipping_Status  \
# 0             Medellín  Base inline    Flete Gratis  No Shipping Payment
# 1         Bogotá, D.c.  Base inline    Flete Gratis  No Shipping Payment
# 2  Cartagena De Indias  Base inline    Flete Gratis  No Shipping Payment
# 3               Cajicá  Base inline             NaN     Shipping Payment
# 4              Barbosa  Base inline    Flete Gratis  No Shipping Payment
#
#         Model                 BU  ... R_cont F_cont   M_cont  R_score  \
# 0  BV2772-010   Apparel Division  ...    625      2   911555        1
# 1  CN8490-002  Footwear Division  ...     77      3  1912885        5
# 2  CU8890-651   Apparel Division  ...    628      2   877941        1
# 3  CV2545-100   Apparel Division  ...    633      1   210042        1
# 4  DC7695-003  Footwear Division  ...    633      1   789832        1
#
#    F_score  M_score  RFM_code     avg_ticket  KMdisc_k7  \
# 0        2        5    R1F2M5  455777.500000          4
# 1        3        5    R5F3M5  637628.333333          5
# 2        2        5    R1F2M5  438970.500000          4
# 3        1        1    R1F1M1  210042.000000          3
# 4        1        4    R1F1M4  789832.000000          0
#
#              cluster_name
# 0  En riesgo (alto valor)
# 1        Leales recientes
# 2  En riesgo (alto valor)
# 3     Dormidos bajo valor
# 4    Ocasionales antiguos
#
# [5 rows x 25 columns]

# %%
# ======================================
# Base de modelado (nivel cliente)
#    Variables: BU_first, Categoria_first, first_disc_group
# ======================================

import pandas as pd
import numpy as np

# Columnas clave
CLIENT_ID          = "Client_Document"
DATE_COL           = "FechaSinHora"
BU_COL             = "BU"
CAT_COL            = "Categoría"
DISCOUNT_NAME_COL  = "Discounts_Names"
GENERO_COL         = "Género"
PAID_COL           = "Valor_Pagado"


# Detectar columna de cluster discreto (k-means)
cluster_col = [c for c in df.columns if c.startswith("KMdisc_k")]
assert len(cluster_col) == 1, "No se encontró la columna de cluster KMdisc_k*."
cluster_col = cluster_col[0]

df = df.copy()
df[DATE_COL] = pd.to_datetime(df[DATE_COL], errors="coerce")
df[CLIENT_ID] = df[CLIENT_ID].astype(str)

# %%
# --------------------------
# Clasificar Discounts_Names
# --------------------------
def clasificar_descuento(nombre):
    if pd.isna(nombre) or str(nombre).strip() == "":
        return "Sin descuento"
    s = str(nombre).lower()

    if "emplead" in s:
        return "Especial empleados"
    if "flete gratis" in s and ("%" not in s):
        return "Solo envío gratis"
    if any(p in s for p in ["10%", "15%", "20%"]):
        return "Descuento bajo (≤20%)"
    if any(p in s for p in ["25%", "30%", "35%"]):
        return "Descuento medio (21–35%)"
    if any(p in s for p in ["40%", "45%", "50%"]):
        return "Descuento alto (≥36%)"
    return "Otros"

df["disc_group_line"] = df[DISCOUNT_NAME_COL].apply(clasificar_descuento)
df["disc_group_line"].value_counts()
# Out:
# disc_group_line
# Solo envío gratis           36062
# Descuento medio (21–35%)    12548
# Descuento bajo (≤20%)       11922
# Descuento alto (≥36%)        8649
# Sin descuento                7750
# Otros                         608
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['FechaSinHora', 'Order', 'Client_Document', 'UF', 'City',
#        'RealDiscount', 'Discounts_Names', 'Shipping_Status', 'Model', 'BU',
#        'Género', 'Categoría', 'Familia_Silueta', 'Unidades', 'Valor_Pagado',
#        'R_cont', 'F_cont', 'M_cont', 'R_score', 'F_score', 'M_score',
#        'RFM_code', 'avg_ticket', 'KMdisc_k7', 'cluster_name',
#        'disc_group_line'],
#       dtype='object')

# %%
df[['City']].value_counts()
# Out:
# City
# Bogotá, D.c.              20315
# Medellín                   9722
# Cali                       5110
# Envigado                   2161
# Barranquilla               1819
#                           ...
# San Andrés De Cuerquía        1
# Soracá                        1
# Contadero                     1
# Contratación                  1
# Polonuevo                     1
# Name: count, Length: 615, dtype: int64

# %%
df[['Categoría']].value_counts()
# Out:
# Categoría
# NIKE SPORTSWEAR       25127
# RUNNING               11366
# JORDAN BRAND           8382
# ATHLETIC TRAINING      7568
# FOOTBALL/SOCCER        7061
# WOMEN TRAINING         6476
# NIKE KIDS              5555
# FOOTBALL/SOCCER AN     3093
# TENNIS                 1326
# BASKETBALL              651
# ACTION SPORTS           588
# YOUNG ATHLETES          243
# SERVICIO                 71
# GOLF                     32
# Name: count, dtype: int64

# %%
# --------------------------
# Primera compra por cliente (categóricas + cluster)
# --------------------------

# Definir ciudades principales
ciudades_principales = ["Bogotá, D.c.", "Bogotá", "Bogotá D.C.", "Medellín"]

df_sorted = df.sort_values([CLIENT_ID, DATE_COL], ascending=True)

# Extraer variables de primera compra
first_purchase = (
    df_sorted
    .groupby(CLIENT_ID, as_index=False)
    .first()
    [[
        CLIENT_ID, BU_COL, CAT_COL, "disc_group_line",
        GENERO_COL, PAID_COL, cluster_col, "cluster_name",
        "City"
    ]]
    .rename(columns={
        BU_COL: "BU_first",
        CAT_COL: "Categoria_first",
        "disc_group_line": "first_disc_group",
        "Género": "Genero_first",
        PAID_COL: "first_ticket",
        cluster_col: "cluster_id",
        "City": "City_first"
    })
)

# Crear flag binario
first_purchase["flg_ciudad_principal"] = first_purchase["City_first"].str.strip().isin(ciudades_principales).astype(int)

first_purchase.head()
# Out:
#   Client_Document           BU_first  Categoria_first  \
# 0           ***02  Footwear Division  NIKE SPORTSWEAR
# 1           ***03  Footwear Division     JORDAN BRAND
# 2           ***07  Footwear Division  NIKE SPORTSWEAR
# 3           ***08  Footwear Division     JORDAN BRAND
# 4           ***10  Footwear Division          RUNNING
#
#            first_disc_group   Genero_first  first_ticket  cluster_id  \
# 0  Descuento medio (21–35%)  HOMBRE (MENS)        479382           2
# 1         Solo envío gratis   JORDAN BRAND        579790           1
# 2     Descuento bajo (≤20%)  HOMBRE (MENS)        615092           5
# 3         Solo envío gratis   JORDAN BRAND        785672           0
# 4         Solo envío gratis  HOMBRE (MENS)        373908           6
#
#            cluster_name       City_first  flg_ciudad_principal
# 0             Champions             Cali                     0
# 1  Nuevos / ticket alto     Bogotá, D.c.                     1
# 2      Leales recientes           Soacha                     0
# 3  Ocasionales antiguos         Rionegro                     0
# 4  Nuevos / ticket bajo  Puente Nacional                     0

# %%
# --------------------------
# Unir todo
# --------------------------

rfm_cont = (
    df.groupby(CLIENT_ID, as_index=False)
      .first()[[CLIENT_ID, "R_cont", "F_cont", "M_cont"]]
)
client_model = first_purchase.merge(rfm_cont, on=CLIENT_ID, how="left")

# Tipos
client_model["cluster_id"] = client_model["cluster_id"].astype(int)
for c in ["BU_first", "Categoria_first", "first_disc_group","Genero_first"]:
    client_model[c] = client_model[c].astype("category")

print("Dimensiones de client_model:", client_model.shape)
client_model.head()
# Out:
# Dimensiones de client_model: (43663, 13)
#   Client_Document           BU_first  Categoria_first  \
# 0           ***02  Footwear Division  NIKE SPORTSWEAR
# 1           ***03  Footwear Division     JORDAN BRAND
# 2           ***07  Footwear Division  NIKE SPORTSWEAR
# 3           ***08  Footwear Division     JORDAN BRAND
# 4           ***10  Footwear Division          RUNNING
#
#            first_disc_group   Genero_first  first_ticket  cluster_id  \
# 0  Descuento medio (21–35%)  HOMBRE (MENS)        479382           2
# 1         Solo envío gratis   JORDAN BRAND        579790           1
# 2     Descuento bajo (≤20%)  HOMBRE (MENS)        615092           5
# 3         Solo envío gratis   JORDAN BRAND        785672           0
# 4         Solo envío gratis  HOMBRE (MENS)        373908           6
#
#            cluster_name       City_first  flg_ciudad_principal  R_cont  \
# 0             Champions             Cali                     0       4
# 1  Nuevos / ticket alto     Bogotá, D.c.                     1     140
# 2      Leales recientes           Soacha                     0     164
# 3  Ocasionales antiguos         Rionegro                     0     349
# 4  Nuevos / ticket bajo  Puente Nacional                     0     155
#
#    F_cont   M_cont
# 0       4  1403585
# 1       1   579790
# 2       2   816731
# 3       1   785672
# 4       1   373908

# %%
df.categoría.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d_/2pvct71j5rz3fqp48s3m8zt40000gn/T/ipykernel_8812/1906765652.py in ?()
# ----> 1 df.categoría.value_counts()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'categoría'

# %% [markdown]
# ### Train/test split

# %%
# ======================================
# Features (X) y target (y)
# ======================================

# Features seleccionadas
cat_features = ["BU_first", "Categoria_first", "first_disc_group","Genero_first"]
num_features = ["first_ticket","flg_ciudad_principal"]
target_col   = "cluster_id"

# One-hot encoding de categóricas
X_cat = pd.get_dummies(
    client_model[cat_features],
    drop_first=False,
    prefix=cat_features
)

# Numéricas continuas
X_num = client_model[num_features].copy()

# Matriz final de features
X = pd.concat([X_num, X_cat], axis=1)
y = client_model[target_col].copy()

print("Shape X:", X.shape)
print("Shape y:", y.shape)
print("\nPrimeras columnas de X:")
X.iloc[:5, :10]
# Out:
# Shape X: (43663, 32)
# Shape y: (43663,)
#
# Primeras columnas de X:
#    first_ticket  flg_ciudad_principal  BU_first_Apparel Division  \
# 0        479382                     0                      False
# 1        579790                     1                      False
# 2        615092                     0                      False
# 3        785672                     0                      False
# 4        373908                     0                      False
#
#    BU_first_Equipment Division  BU_first_Footwear Division  BU_first_Otro  \
# 0                        False                        True          False
# 1                        False                        True          False
# 2                        False                        True          False
# 3                        False                        True          False
# 4                        False                        True          False
#
#    Categoria_first_ACTION SPORTS  Categoria_first_ATHLETIC TRAINING  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
#
#    Categoria_first_BASKETBALL  Categoria_first_FOOTBALL/SOCCER
# 0                       False                            False
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                            False

# %%
# ======================================
# Train/Test Split (estratificado por cluster)
# ======================================
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

print("Tamaños:")
print(" - X_train:", X_train.shape)
print(" - X_test : ", X_test.shape)

print("\nDistribución y_train:")
print(y_train.value_counts(normalize=True).sort_index().round(3))

print("\nDistribución y_test:")
print(y_test.value_counts(normalize=True).sort_index().round(3))
# Out:
# Tamaños:
#  - X_train: (30564, 32)
#  - X_test :  (13099, 32)
#
# Distribución y_train:
# cluster_id
# 0    0.186
# 1    0.229
# 2    0.026
# 3    0.172
# 4    0.072
# 5    0.085
# 6    0.228
# Name: proportion, dtype: float64
#
# Distribución y_test:
# cluster_id
# 0    0.186
# 1    0.229
# 2    0.026
# 3    0.172
# 4    0.072
# 5    0.085
# 6    0.228
# Name: proportion, dtype: float64

# %% [markdown]
# # Modelo 1: Arbol de decisión

# %%
# ======================================
# Librerías requeridas
# ======================================

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# %%
# ======================================
# Árbol de Decisión
# ======================================
dt_clf = DecisionTreeClassifier(
    max_depth=6,          
    min_samples_leaf=200, # subir hojas mínimas para evitar sobreajuste
    random_state=42,
    class_weight="balanced"
)

dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=6,
#                        min_samples_leaf=200, random_state=42)

# %%
# ======================================
# Evaluación del Árbol de Decisión
# ======================================

# Predicciones en test
y_pred = dt_clf.predict(X_test)

acc_dt = accuracy_score(y_test, y_pred)
bal_dtc = balanced_accuracy_score(y_test, y_pred)
f1_dt = f1_score(y_test, y_pred, average="macro")

print(f"Accuracy  : {acc_dt:.3f}")
print(f"Balanced Accuracy:   {bal_dtc:.3f}")
print(f"F1 macro : {f1_dt:.3f}\n")

print("Reporte de clasificación por cluster:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Accuracy  : 0.426
# Balanced Accuracy:   0.325
# F1 macro : 0.290
#
# Reporte de clasificación por cluster:
#               precision    recall  f1-score   support
#
#            0      0.401     0.543     0.461      2438
#            1      0.472     0.428     0.449      3004
#            2      0.090     0.125     0.105       345
#            3      0.385     0.783     0.516      2259
#            4      0.146     0.015     0.027       949
#            5      0.000     0.000     0.000      1115
#            6      0.604     0.385     0.470      2989
#
#     accuracy                          0.426     13099
#    macro avg      0.300     0.325     0.290     13099
# weighted avg      0.400     0.426     0.390     13099
# /Users/josemedina/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/josemedina/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/josemedina/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# ======================================
# Matriz de confusión
# ======================================

# Nombres de los clusters
client_model["cluster_id"] = client_model["cluster_id"].astype(int)
client_model["cluster_name"] = client_model["cluster_name"].astype(str)

id_to_name = (
    client_model[["cluster_id", "cluster_name"]]
    .drop_duplicates()
    .sort_values("cluster_id")
    .set_index("cluster_id")["cluster_name"]
    .to_dict()
)

cluster_ids = sorted(id_to_name.keys())
labels_txt = [f"{cid} - {id_to_name[cid]}" for cid in cluster_ids]

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred, labels=cluster_ids)

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)
plt.xlabel("Predicho")
plt.ylabel("Real")
plt.title("Matriz de confusión modelo 1. Arbol de decisión")
plt.tight_layout()
plt.show()

# %%
# ======================================
# 7. Importancia de variables
# ======================================

fi = pd.DataFrame({
    "feature": X.columns,
    "importance": dt_clf.feature_importances_
}).sort_values("importance", ascending=False)

fi = fi[fi["importance"] > 0]

print("Top 15 variables más importantes:")
display(fi.head(15))

plt.figure(figsize=(8,5))
sns.barplot(
    data=fi.head(15),
    x="importance",
    y="feature"
)
plt.title("Importancia de variables — Árbol (RFM continuo + categóricas)")
plt.tight_layout()
plt.show()
# Out:
# Top 15 variables más importantes:
#                                    feature  importance
# 0                             first_ticket    0.804947
# 10      Categoria_first_FOOTBALL/SOCCER AN    0.075068
# 25      first_disc_group_Solo envío gratis    0.040209
# 29               Genero_first_NIÑOS (KIDS)    0.019515
# 20  first_disc_group_Descuento alto (≥36%)    0.017654
# 2                BU_first_Apparel Division    0.017278
# 14         Categoria_first_NIKE SPORTSWEAR    0.011797
# 24          first_disc_group_Sin descuento    0.006204
# 9          Categoria_first_FOOTBALL/SOCCER    0.004391
# 7        Categoria_first_ATHLETIC TRAINING    0.002587
# 1                     flg_ciudad_principal    0.000349

# %% [markdown]
# # Modelo 2: Redes neuronales

# %%
# ======================================
# Librerías requeridas
# ======================================

from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
# ======================================
# Escalado de features para red neuronal
# ======================================

scaler_nn = StandardScaler()

# Ajustamos el scaler solo con train y lo aplicamos a train y test
X_train_nn = scaler_nn.fit_transform(X_train)
X_test_nn  = scaler_nn.transform(X_test)

print("Shapes escalados:")
print("X_train_nn:", X_train_nn.shape)
print("X_test_nn :", X_test_nn.shape)
# Out:
# Shapes escalados:
# X_train_nn: (30564, 32)
# X_test_nn : (13099, 32)

# %%
# ======================================
# Modelo: Red Neuronal (MLPClassifier)
# ======================================

mlp_clf = MLPClassifier(
    hidden_layer_sizes=(64, 32),  # dos capas ocultas: 64 y 32 neuronas
    activation="relu",
    solver="adam",
    alpha=1e-4,          # regularización L2
    batch_size="auto",
    learning_rate="adaptive",
    max_iter=200,
    random_state=42,
    early_stopping=True,  # usa parte del train como validación interna
    n_iter_no_change=10,
    verbose=False
)

mlp_clf.fit(X_train_nn, y_train)

print("Red neuronal entrenada")
print("N_iter (épocas realmente usadas):", mlp_clf.n_iter_)
# Out:
# Red neuronal entrenada
# N_iter (épocas realmente usadas): 55

# %%
# ======================================
# Evaluación de la Red Neuronal
# ======================================

# Predicciones
y_pred_mlp = mlp_clf.predict(X_test_nn)

acc_mlp = accuracy_score(y_test, y_pred_mlp)
bal_acc = balanced_accuracy_score(y_test, y_pred_mlp)
f1_mlp  = f1_score(y_test, y_pred_mlp, average="macro")

print(f"Accuracy  (MLP): {acc_mlp:.3f}")
print(f"Balanced Accuracy:   {bal_acc:.3f}")
print(f"F1 macro (MLP): {f1_mlp:.3f}\n")

print("Reporte de clasificación — Red Neuronal:")
print(classification_report(y_test, y_pred_mlp, digits=3))

acc = accuracy_score(y_test, y_pred_mlp2)
bal_acc = balanced_accuracy_score(y_test, y_pred_mlp2)
f1 = f1_score(y_test, y_pred_mlp2, average="macro")
# Out:
# Accuracy  (MLP): 0.481
# Balanced Accuracy:   0.328
# F1 macro (MLP): 0.293
#
# Reporte de clasificación — Red Neuronal:
#               precision    recall  f1-score   support
#
#            0      0.439     0.319     0.369      2438
#            1      0.463     0.700     0.558      3004
#            2      0.000     0.000     0.000       345
#            3      0.470     0.516     0.492      2259
#            4      0.107     0.003     0.006       949
#            5      0.087     0.002     0.004      1115
#            6      0.529     0.753     0.621      2989
#
#     accuracy                          0.481     13099
#    macro avg      0.299     0.328     0.293     13099
# weighted avg      0.405     0.481     0.424     13099
# /Users/josemedina/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/josemedina/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/josemedina/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# ======================================
# Matriz de confusión
# ======================================

# Nombres de los clusters
client_model["cluster_id"] = client_model["cluster_id"].astype(int)
client_model["cluster_name"] = client_model["cluster_name"].astype(str)

id_to_name = (
    client_model[["cluster_id", "cluster_name"]]
    .drop_duplicates()
    .sort_values("cluster_id")
    .set_index("cluster_id")["cluster_name"]
    .to_dict()
)

cluster_ids = sorted(id_to_name.keys())
labels_txt = [f"{cid} - {id_to_name[cid]}" for cid in cluster_ids]

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred_mlp, labels=cluster_ids)

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Purples"
)
plt.xlabel("Predicho")
plt.ylabel("Real")
plt.title("Matriz de confusión modelo 2. Redes Neuronales")
plt.tight_layout()
plt.show()

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score, balanced_accuracy_score, classification_report
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd

# ======================================
# Calcular pesos de clase
# ======================================

classes = np.unique(y_train)
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)

class_weight_dict = {cls: w for cls, w in zip(classes, class_weights)}

print("Pesos de clase usados para oversampling:")
print(class_weight_dict)

# ======================================
# Construir conjunto balanceado por oversampling ponderado
# ======================================

# Si X_train_nn es un array, lo convertimos a DataFrame
if isinstance(X_train_nn, np.ndarray):
    df_train = pd.DataFrame(X_train_nn)
else:
    df_train = X_train_nn.copy()

df_train = df_train.copy()
df_train["y"] = y_train.values

df_balanced_list = []

for cls, w in class_weight_dict.items():
    temp = df_train[df_train["y"] == cls]
    # número de repeticiones proporcional al peso (al menos 1)
    reps = int(np.ceil(w))
    reps = max(reps, 1)
    df_balanced_list.append(pd.concat([temp] * reps, axis=0))

df_balanced = pd.concat(df_balanced_list, axis=0)
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

X_train_bal = df_balanced.drop(columns=["y"])
y_train_bal = df_balanced["y"]

print("Tamaño original X_train_nn:", X_train_nn.shape)
print("Tamaño balanceado X_train_bal:", X_train_bal.shape)
# Out:
# Pesos de clase usados para oversampling:
# {0: 0.7676311030741411, 1: 0.6229541609767034, 2: 5.430703624733476, 3: 0.8285172133369477, 4: 1.9712350854563043, 5: 1.6780498517623805, 6: 0.6259010484927916}
# Tamaño original X_train_nn: (30564, 32)
# Tamaño balanceado X_train_bal: (39401, 32)

# %% [markdown]
#     2: "Champions",
#     5: "Leales recientes",
#     4: "En riesgo (alto valor)",
#     0: "Ocasionales antiguos",
#     1: "Nuevos / ticket alto",
#     6: "Nuevos / ticket bajo",
#     3: "Dormidos bajo valor",

# %%
mlp_clf2 = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32),   # 3 capas ocultas
    activation="relu",
    solver="adam",
    alpha=1e-5,                         # menos regularización
    learning_rate="adaptive",
    max_iter=400,
    random_state=42,
    early_stopping=True,                # validación interna
    n_iter_no_change=20,
    verbose=False
)

mlp_clf2.fit(X_train_bal, y_train_bal)

print("Red neuronal entrenada")
print("Épocas utilizadas:", mlp_clf2.n_iter_)

# ======================================
# Evaluación en el conjunto de test original
# ======================================

y_pred_mlp2 = mlp_clf2.predict(X_test_nn)

acc = accuracy_score(y_test, y_pred_mlp2)
bal_acc = balanced_accuracy_score(y_test, y_pred_mlp2)
f1 = f1_score(y_test, y_pred_mlp2, average="macro")

print(f"Accuracy:            {acc:.3f}")
print(f"Balanced Accuracy:   {bal_acc:.3f}")
print(f"F1 macro:            {f1:.3f}\n")

print("Reporte de clasificación:")
print(classification_report(y_test, y_pred_mlp2, digits=3))
# Out:
# Red neuronal entrenada
# Épocas utilizadas: 157
# Accuracy:            0.461
# Balanced Accuracy:   0.346
# F1 macro:            0.328
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0      0.447     0.473     0.459      2438
#            1      0.513     0.533     0.523      3004
#            2      0.059     0.162     0.087       345
#            3      0.492     0.564     0.526      2259
#            4      0.122     0.028     0.046       949
#            5      0.081     0.030     0.044      1115
#            6      0.589     0.634     0.611      2989
#
#     accuracy                          0.461     13099
#    macro avg      0.329     0.346     0.328     13099
# weighted avg      0.437     0.461     0.445     13099

# %% [markdown]
# # Modelo 3: XGBoost

# %%
# ======================================
# Librerías requeridas
# ======================================
import xgboost as xgb
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
# ======================================
# Modelo: XGBoost (XGBClassifier)
# ======================================
num_classes = y.nunique()

xgb_clf = xgb.XGBClassifier(
    objective="multi:softprob",
    num_class=num_classes,
    eval_metric="mlogloss",
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    tree_method="hist"  # rápido y eficiente
)

xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_class=7, num_parallel_tree=None, ...)

# %%
# ======================================
# Evaluación de XGBoost
# ======================================

# Predicciones
y_pred_xgb = xgb_clf.predict(X_test)

acc_xgb = accuracy_score(y_test, y_pred_xgb)
bal_xgb = balanced_accuracy_score(y_test, y_pred_xgb)
f1_xgb  = f1_score(y_test, y_pred_xgb, average="macro")

print(f"Accuracy  (XGB): {acc_xgb:.3f}")
print(f"Balanced Accuracy:   {bal_xgb:.3f}")
print(f"F1 macro (XGB): {f1_xgb:.3f}\n")

print("Reporte de clasificación — XGBoost:")
print(classification_report(y_test, y_pred_xgb, digits=3))
# Out:
# Accuracy  (XGB): 0.555
# Balanced Accuracy:   0.385
# F1 macro (XGB): 0.350
#
# Reporte de clasificación — XGBoost:
#               precision    recall  f1-score   support
#
#            0      0.530     0.519     0.524      2438
#            1      0.554     0.715     0.624      3004
#            2      0.222     0.006     0.011       345
#            3      0.545     0.620     0.580      2259
#            4      0.229     0.012     0.022       949
#            5      0.162     0.005     0.010      1115
#            6      0.584     0.815     0.680      2989
#
#     accuracy                          0.555     13099
#    macro avg      0.404     0.385     0.350     13099
# weighted avg      0.489     0.555     0.499     13099

# %%
# ======================================
# Matriz de confusión
# ======================================

# Nombres de los clusters
client_model["cluster_id"] = client_model["cluster_id"].astype(int)
client_model["cluster_name"] = client_model["cluster_name"].astype(str)

id_to_name = (
    client_model[["cluster_id", "cluster_name"]]
    .drop_duplicates()
    .sort_values("cluster_id")
    .set_index("cluster_id")["cluster_name"]
    .to_dict()
)

cluster_ids = sorted(id_to_name.keys())
labels_txt = [f"{cid} - {id_to_name[cid]}" for cid in cluster_ids]

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred_xgb, labels=cluster_ids)

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Greens"
)
plt.xlabel("Predicho")
plt.ylabel("Real")
plt.title("Matriz de confusión modelo 3. XGBoost")
plt.tight_layout()
plt.show()

# %%
# ======================================
# Importancia de variables — XGBoost
# ======================================

fi_xgb = pd.DataFrame({
    "feature": X.columns,
    "importance": xgb_clf.feature_importances_
}).sort_values("importance", ascending=False)

fi_xgb = fi_xgb[fi_xgb["importance"] > 0]

print("Top 15 variables más importantes (XGBoost):")
display(fi_xgb.head(15))

plt.figure(figsize=(8,5))
sns.barplot(
    data=fi_xgb.head(15),
    x="importance",
    y="feature"
)
plt.title("Importancia de variables — XGBoost")
plt.tight_layout()
plt.show()
# Out:
# Top 15 variables más importantes (XGBoost):
#                                    feature  importance
# 4               BU_first_Footwear Division    0.126540
# 0                             first_ticket    0.099826
# 24          first_disc_group_Sin descuento    0.076235
# 10      Categoria_first_FOOTBALL/SOCCER AN    0.072201
# 25      first_disc_group_Solo envío gratis    0.055471
# 29               Genero_first_NIÑOS (KIDS)    0.051742
# 5                            BU_first_Otro    0.047671
# 20  first_disc_group_Descuento alto (≥36%)    0.031590
# 12            Categoria_first_JORDAN BRAND    0.029867
# 27               Genero_first_JORDAN BRAND    0.028981
# 9          Categoria_first_FOOTBALL/SOCCER    0.028482
# 6            Categoria_first_ACTION SPORTS    0.024884
# 2                BU_first_Apparel Division    0.022424
# 21  first_disc_group_Descuento bajo (≤20%)    0.021276
# 3              BU_first_Equipment Division    0.020440

# %%
# ======================================
# 6. Comparación: Árbol vs MLP vs XGBoost
# ======================================

resumen_modelos = pd.DataFrame({
    "modelo": ["Árbol de decisión", "Red neuronal (MLP)", "XGBoost"],
    "accuracy": [acc_dt, acc_mlp, acc_xgb],
    "f1_macro": [f1_dt, f1_mlp, f1_xgb],
    "Balanced Accuracy": [bal_dtc,bal_acc,bal_xgb]
})

print("Comparación de desempeño (test):")
display(resumen_modelos)
# Out:
# Comparación de desempeño (test):
#                modelo  accuracy  f1_macro  Balanced Accuracy
# 0   Árbol de decisión  0.426445  0.289720           0.325469
# 1  Red neuronal (MLP)  0.481029  0.292764           0.346433
# 2             XGBoost  0.554852  0.350402           0.384503

# %% [markdown]
# Los tres modelos evaluados presentan desempeños moderados, lo cual es habitual en problemas de clasificación temprana basados únicamente en la primera compra del cliente. Entre ellos, XGBoost alcanza las mejores métricas, por lo que se selecciona como el modelo base para aplicar Conformal Prediction.

# %% [markdown]
# # Conformal prediction

# %%
# ======================================
# Split interno: train - (train_model, calibration)
# ======================================
X_train_model, X_calib, y_train_model, y_calib = train_test_split(
    X_train, y_train,
    test_size=0.20,          # 20% calibración es estándar
    random_state=42,
    stratify=y_train
)

X_train_model.shape, X_calib.shape
# Out:
# ((24451, 32), (6113, 32))

# %%
# ======================================
# Reentrenar XGBoost con subtraining (train_model)
# ======================================
num_classes = y.nunique()

xgb_cp = xgb.XGBClassifier(
    objective="multi:softprob",
    num_class=num_classes,
    eval_metric="mlogloss",
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    tree_method="hist"
)

xgb_cp.fit(X_train_model, y_train_model)

print("XGBoost reentrenado para Conformal Prediction")
# Out:
# XGBoost reentrenado para Conformal Prediction

# %%
# ======================================
# Nonconformity scores en calibration set
# ======================================

# Probabilidades predichas en calibración
probs_calib = xgb_cp.predict_proba(X_calib)

# Nonconformity: 1 - prob(real_class)
alpha_scores = 1 - probs_calib[np.arange(len(y_calib)), y_calib.values]

alpha_scores[:10]  # vista rápida
# Out:
# array([0.33907187, 0.7684324 , 0.34613323, 0.43697834, 0.640697  ,
#        0.88038176, 0.8678976 , 0.5124491 , 0.685861  , 0.37357134],
#       dtype=float32)

# %%
# ======================================
# Función generadora de prediction sets
# ======================================
def conformal_prediction_set(probs, alpha_scores, alpha=0.10):
    """
    probs: vector de probabilidades predichas (1 x num_classes)
    alpha_scores: nonconformity calibrados
    alpha: nivel de error deseado (ej. 0.10 = 90% confianza)
    """
    # Umbral conformal
    q_hat = np.quantile(alpha_scores, 1 - alpha, interpolation="higher")
    
    prediction_set = []
    for c in range(len(probs)):
        nonconf = 1 - probs[c]
        if nonconf <= q_hat:
            prediction_set.append(c)
    return prediction_set, q_hat

# %%
# ======================================
# Aplicar Conformal Prediction al test set
# ======================================
probs_test = xgb_cp.predict_proba(X_test)

alpha = 0.1  # 90% confianza (puedes usar 0.05 para 95%)

prediction_sets = []
set_sizes = []

for i in range(len(X_test)):
    ps, q_hat = conformal_prediction_set(
        probs_test[i],
        alpha_scores,
        alpha=alpha
    )
    prediction_sets.append(ps)
    set_sizes.append(len(ps))

print("q_hat (umbral conformal):", q_hat)
print("Tamaño promedio prediction set:", np.mean(set_sizes))
print("Porcentaje de sets con tamaño 1:", np.mean(np.array(set_sizes)==1))
print("Porcentaje de sets con tamaño >1:", np.mean(np.array(set_sizes)>1))
# Out:
# /var/folders/d_/2pvct71j5rz3fqp48s3m8zt40000gn/T/ipykernel_8812/2974756213.py:11: DeprecationWarning: the `interpolation=` argument to quantile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   q_hat = np.quantile(alpha_scores, 1 - alpha, interpolation="higher")
# q_hat (umbral conformal): 0.927518
# Tamaño promedio prediction set: 3.294373616306588
# Porcentaje de sets con tamaño 1: 0.03404840064127033
# Porcentaje de sets con tamaño >1: 0.9659515993587297

# %%
# ======================================
# Validación: ¿el cluster real está dentro del prediction set?
# ======================================
y_test_arr = y_test.values

coverage = np.mean([
    y_test_arr[i] in prediction_sets[i]
    for i in range(len(y_test_arr))
])

print(f"Cobertura real obtenida: {coverage:.3f} (esperada ≥ {1-alpha})")
# Out:
# Cobertura real obtenida: 0.905 (esperada ≥ 0.9)

# %%
# ======================================
# DataFrame final de resultados
# ======================================
df_conformal = pd.DataFrame({
    "real_cluster": y_test_arr,
    "prediction": xgb_cp.predict(X_test),
    "prediction_set": prediction_sets,
    "set_size": set_sizes
})

df_conformal.head(10)
# Out:
#    real_cluster  prediction         prediction_set  set_size
# 0             0           1  [0, 1, 2, 3, 4, 5, 6]         7
# 1             1           1              [0, 1, 5]         3
# 2             5           1              [0, 1, 5]         3
# 3             1           6        [1, 3, 4, 5, 6]         5
# 4             1           1           [0, 1, 4, 5]         4
# 5             2           1     [0, 1, 3, 4, 5, 6]         6
# 6             6           6           [1, 3, 5, 6]         4
# 7             4           1              [0, 1, 5]         3
# 8             3           3           [3, 4, 5, 6]         4
# 9             3           3              [3, 5, 6]         3

# %%
df_conformal.set_size.value_counts()
# Out:
# set_size
# 3    4526
# 4    3941
# 2    2820
# 5     676
# 6     485
# 1     446
# 7     205
# Name: count, dtype: int64

# %%
df_conformal[df_conformal['set_size']==2].prediction_set.value_counts()
# Out:
# prediction_set
# [3, 6]    2046
# [0, 1]     405
# [3, 4]     150
# [0, 4]      80
# [1, 5]      64
# [5, 6]      40
# [4, 6]      14
# [3, 5]      10
# [1, 6]       8
# [1, 4]       2
# [0, 3]       1
# Name: count, dtype: int64

# %% [markdown]
#     2: "Champions",
#     5: "Leales recientes",
#     4: "En riesgo (alto valor)",
#     0: "Ocasionales antiguos",
#     1: "Nuevos / ticket alto",
#     6: "Nuevos / ticket bajo",
#     3: "Dormidos bajo valor",

# %%
df_conformal.shape
# Out:
# (13099, 4)

# %%
df_conformal[(df_conformal['set_size']==2)]
# Out:
#        real_cluster  prediction prediction_set  set_size
# 13                3           6         [3, 6]         2
# 14                1           6         [5, 6]         2
# 16                4           6         [3, 6]         2
# 18                6           6         [3, 6]         2
# 19                6           3         [3, 6]         2
# ...             ...         ...            ...       ...
# 13085             3           6         [3, 6]         2
# 13090             3           3         [3, 6]         2
# 13091             3           6         [3, 6]         2
# 13092             0           1         [0, 1]         2
# 13096             2           3         [3, 6]         2
#
# [2820 rows x 4 columns]

# %%
df_conformal[
    df_conformal["set_size"].isin([1,2,3,4]) &
    df_conformal["prediction_set"].apply(lambda x: any(v in x for v in [4, 5]))
].shape
# Out:
# (8454, 4)

# %%
8454/13099
# Out:
# 0.6453927780746622

# %%
4540/13099
# Out:
# 0.3465913428505993

# %%
(2046+405)/13099
# Out:
# 0.1871135201160394

# %%
df_conformal[
    df_conformal["set_size"].isin([3]) &
    df_conformal["prediction_set"].apply(lambda x: any(v in x for v in [4, 5]))
].shape
# Out:
# (4235, 4)

# %%
gasto_mercadeo = 120000000
clientes_nuevos = 2000
valor_bono = 100000
gasto_x_cliente = gasto_mercadeo/clientes_nuevos

grupo_1_potenciales = round(2000*0.6453)
grupo_2_descuento = round(2000*0.1871)
grupo_3_no_hacer_nada = round(2000*(1-0.1871-0.6453))

# %%
print(grupo_1_potenciales)
print(grupo_2_descuento)
print(grupo_3_no_hacer_nada)
# Out:
# 1291
# 374
# 335

# %%
1294*gasto_x_cliente
# Out:
# 77640000.0

# %%
gasto_mercadeo-1294*gasto_x_cliente
# Out:
# 42360000.0

# %%
valor_bono*grupo_2_descuento*0.2
# Out:
# 7480000.0

# %%
77640000.0+7880000
# Out:
# 85520000.0

# %%
1291*0.3 #minimo porcentaje de conversión para hacer que la estrategia tenga sentido
# Out:
# 387.3

# %%
(387+(394*0.2))/2000
# Out:
# 0.2329

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# Nivel de error deseado para Conformal Prediction
alpha = 0.10  # 90% de confianza

# ======================================
# Split común: train_model vs calibration
# (usamos índices para poder reutilizar en X_train_nn)
# ======================================

n_train = len(X_train)
idx = np.arange(n_train)

idx_train_model, idx_calib = train_test_split(
    idx,
    test_size=0.20,
    random_state=42,
    stratify=y_train
)

# Subconjunto para entrenar modelos
X_train_model = X_train.iloc[idx_train_model]
y_train_model = y_train.iloc[idx_train_model]

X_calib       = X_train.iloc[idx_calib]
y_calib       = y_train.iloc[idx_calib]

print("Shapes base:")
print("X_train_model:", X_train_model.shape)
print("X_calib:", X_calib.shape)

# Si tienes matrices normalizadas para la red neuronal
# (X_train_nn, X_test_nn), hacemos el mismo split por posiciones
X_train_nn_model = X_train_nn[idx_train_model]
X_calib_nn       = X_train_nn[idx_calib]

print("X_train_nn_model:", X_train_nn_model.shape)
print("X_calib_nn:", X_calib_nn.shape)

# ======================================
# Funciones auxiliares de Conformal Prediction
# ======================================

def conformal_prediction_set(probs_row, alpha_scores, alpha=0.10):
    """
    probs_row: vector de probabilidades predichas para una observación (shape: [n_clases])
    alpha_scores: nonconformity scores en el set de calibración (1 - prob(clase real))
    alpha: nivel de error deseado (0.10 => 90% confianza)
    """
    # Umbral conformal
    q_hat = np.quantile(alpha_scores, 1 - alpha, method="higher")
    
    prediction_set = []
    for c in range(len(probs_row)):
        nonconf = 1 - probs_row[c]
        if nonconf <= q_hat:
            prediction_set.append(c)
    return prediction_set, q_hat

def evaluar_conformal(y_test, prediction_sets, y_pred_point, alpha):
    """
    Calcula métricas de evaluación del Conformal Prediction:
      - cobertura (que el label real esté dentro del prediction set)
      - tamaño promedio del set
      - % sets unitarios
      - % sets de tamaño >1
    """
    y_test_arr = np.array(y_test)
    set_sizes = np.array([len(ps) for ps in prediction_sets])
    
    coverage = np.mean([
        y_test_arr[i] in prediction_sets[i]
        for i in range(len(y_test_arr))
    ])
    
    pct_singletons = np.mean(set_sizes == 1)
    pct_multi      = np.mean(set_sizes > 1)
    avg_size       = np.mean(set_sizes)
    
    return {
        "alpha": alpha,
        "coverage": coverage,
        "avg_set_size": avg_size,
        "pct_singletons": pct_singletons,
        "pct_multi": pct_multi
    }
# Out:
# Shapes base:
# X_train_model: (24451, 32)
# X_calib: (6113, 32)
# X_train_nn_model: (24451, 32)
# X_calib_nn: (6113, 32)

# %%
import xgboost as xgb

# ======================================
# 1. Reentrenar XGBoost con X_train_model
# ======================================

num_classes = y.nunique()

xgb_cp = xgb.XGBClassifier(
    objective="multi:softprob",
    num_class=num_classes,
    eval_metric="mlogloss",
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    tree_method="hist"
)

xgb_cp.fit(X_train_model, y_train_model)

print("XGBoost reentrenado para Conformal Prediction")

# ======================================
# 2. Nonconformity scores en calibration set
# ======================================

probs_calib_xgb = xgb_cp.predict_proba(X_calib)
alpha_scores_xgb = 1 - probs_calib_xgb[np.arange(len(y_calib)), y_calib.values]

# ======================================
# 3. Aplicar Conformal Prediction al test set
# ======================================

probs_test_xgb = xgb_cp.predict_proba(X_test)

prediction_sets_xgb = []
set_sizes_xgb = []

for i in range(len(X_test)):
    ps, q_hat_xgb = conformal_prediction_set(
        probs_test_xgb[i],
        alpha_scores_xgb,
        alpha=alpha
    )
    prediction_sets_xgb.append(ps)
    set_sizes_xgb.append(len(ps))

print("q_hat (XGBoost):", q_hat_xgb)

# Predicción puntual (clásica) del modelo
y_pred_point_xgb = xgb_cp.predict(X_test)

# ======================================
# 4. Métricas de cobertura y tamaño de set
# ======================================

metrics_xgb = evaluar_conformal(
    y_test=y_test,
    prediction_sets=prediction_sets_xgb,
    y_pred_point=y_pred_point_xgb,
    alpha=alpha
)

print("Métricas Conformal - XGBoost:")
for k, v in metrics_xgb.items():
    print(f"{k}: {v:.3f}" if isinstance(v, float) else f"{k}: {v}")

# ======================================
# 5. DataFrame de resultados CP para XGBoost
# ======================================

df_conformal_xgb = pd.DataFrame({
    "real_cluster": y_test.values,
    "prediction": y_pred_point_xgb,
    "prediction_set": prediction_sets_xgb,
    "set_size": set_sizes_xgb
})

df_conformal_xgb.head()
# Out:
# XGBoost reentrenado para Conformal Prediction
# q_hat (XGBoost): 0.927518
# Métricas Conformal - XGBoost:
# alpha: 0.100
# coverage: 0.905
# avg_set_size: 3.294
# pct_singletons: 0.034
# pct_multi: 0.966
#    real_cluster  prediction         prediction_set  set_size
# 0             0           1  [0, 1, 2, 3, 4, 5, 6]         7
# 1             1           1              [0, 1, 5]         3
# 2             5           1              [0, 1, 5]         3
# 3             1           6        [1, 3, 4, 5, 6]         5
# 4             1           1           [0, 1, 4, 5]         4

# %%
from sklearn.tree import DecisionTreeClassifier

# ======================================
# 1. Reentrenar Árbol de Decisión con X_train_model
# ======================================

dt_cp = DecisionTreeClassifier(
    max_depth=None,          # ajusta según tu modelo previo
    min_samples_leaf=5,      # ejemplo, cambia si usaste otros
    random_state=42
)

dt_cp.fit(X_train_model, y_train_model)

print("Árbol de decisión reentrenado para Conformal Prediction")

# ======================================
# 2. Nonconformity scores en calibration set
# ======================================

probs_calib_dt = dt_cp.predict_proba(X_calib)
alpha_scores_dt = 1 - probs_calib_dt[np.arange(len(y_calib)), y_calib.values]

# ======================================
# 3. Aplicar Conformal Prediction al test set
# ======================================

probs_test_dt = dt_cp.predict_proba(X_test)

prediction_sets_dt = []
set_sizes_dt = []

for i in range(len(X_test)):
    ps, q_hat_dt = conformal_prediction_set(
        probs_test_dt[i],
        alpha_scores_dt,
        alpha=alpha
    )
    prediction_sets_dt.append(ps)
    set_sizes_dt.append(len(ps))

print("q_hat (Árbol):", q_hat_dt)

y_pred_point_dt = dt_cp.predict(X_test)

# ======================================
# 4. Métricas Conformal para Árbol
# ======================================

metrics_dt = evaluar_conformal(
    y_test=y_test,
    prediction_sets=prediction_sets_dt,
    y_pred_point=y_pred_point_dt,
    alpha=alpha
)

print("Métricas Conformal - Árbol de decisión:")
for k, v in metrics_dt.items():
    print(f"{k}: {v:.3f}" if isinstance(v, float) else f"{k}: {v}")

# ======================================
# 5. DataFrame de resultados CP para Árbol
# ======================================

df_conformal_dt = pd.DataFrame({
    "real_cluster": y_test.values,
    "prediction": y_pred_point_dt,
    "prediction_set": prediction_sets_dt,
    "set_size": set_sizes_dt
})

df_conformal_dt.head()
# Out:
# Árbol de decisión reentrenado para Conformal Prediction
# q_hat (Árbol): 1.0
# Métricas Conformal - Árbol de decisión:
# alpha: 0.100
# coverage: 1.000
# avg_set_size: 7.000
# pct_singletons: 0.000
# pct_multi: 1.000
#    real_cluster  prediction         prediction_set  set_size
# 0             0           0  [0, 1, 2, 3, 4, 5, 6]         7
# 1             1           1  [0, 1, 2, 3, 4, 5, 6]         7
# 2             5           0  [0, 1, 2, 3, 4, 5, 6]         7
# 3             1           0  [0, 1, 2, 3, 4, 5, 6]         7
# 4             1           0  [0, 1, 2, 3, 4, 5, 6]         7

# %%
from sklearn.neural_network import MLPClassifier

# ======================================
# 1. Reentrenar MLP con X_train_nn_model
#    (puedes incorporar oversampling aquí si quieres replicar el esquema anterior)
# ======================================

mlp_cp = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32),
    activation="relu",
    solver="adam",
    alpha=1e-5,
    learning_rate="adaptive",
    max_iter=400,
    random_state=42,
    early_stopping=True,
    n_iter_no_change=20,
    verbose=False
)

mlp_cp.fit(X_train_nn_model, y_train_model)

print("MLP reentrenada para Conformal Prediction")

# ======================================
# 2. Nonconformity scores en calibration set (versión NN)
# ======================================

probs_calib_mlp = mlp_cp.predict_proba(X_calib_nn)
alpha_scores_mlp = 1 - probs_calib_mlp[np.arange(len(y_calib)), y_calib.values]

# ======================================
# 3. Aplicar Conformal Prediction al test set (NN)
# ======================================

probs_test_mlp = mlp_cp.predict_proba(X_test_nn)

prediction_sets_mlp = []
set_sizes_mlp = []

for i in range(len(X_test_nn)):
    ps, q_hat_mlp = conformal_prediction_set(
        probs_test_mlp[i],
        alpha_scores_mlp,
        alpha=alpha
    )
    prediction_sets_mlp.append(ps)
    set_sizes_mlp.append(len(ps))

print("q_hat (MLP):", q_hat_mlp)

y_pred_point_mlp = mlp_cp.predict(X_test_nn)

# ======================================
# 4. Métricas Conformal para MLP
# ======================================

metrics_mlp = evaluar_conformal(
    y_test=y_test,
    prediction_sets=prediction_sets_mlp,
    y_pred_point=y_pred_point_mlp,
    alpha=alpha
)

print("Métricas Conformal - MLP:")
for k, v in metrics_mlp.items():
    print(f"{k}: {v:.3f}" if isinstance(v, float) else f"{k}: {v}")

# ======================================
# 5. DataFrame de resultados CP para MLP
# ======================================

df_conformal_mlp = pd.DataFrame({
    "real_cluster": y_test.values,
    "prediction": y_pred_point_mlp,
    "prediction_set": prediction_sets_mlp,
    "set_size": set_sizes_mlp
})

df_conformal_mlp.head()
# Out:
# MLP reentrenada para Conformal Prediction
# q_hat (MLP): 0.9357100533765788
# Métricas Conformal - MLP:
# alpha: 0.100
# coverage: 0.904
# avg_set_size: 3.397
# pct_singletons: 0.042
# pct_multi: 0.958
#    real_cluster  prediction      prediction_set  set_size
# 0             0           3  [0, 1, 2, 3, 4, 5]         6
# 1             1           1        [0, 1, 4, 5]         4
# 2             5           0              [0, 1]         2
# 3             1           6  [0, 1, 3, 4, 5, 6]         6
# 4             1           1        [0, 1, 4, 5]         4

# %%
# Consolidación de métricas CP en un solo cuadro

df_metrics_cp = pd.DataFrame([
    {"modelo": "Árbol de decisión", **metrics_dt},
    {"modelo": "Red neuronal (MLP)", **metrics_mlp},
    {"modelo": "XGBoost", **metrics_xgb},
])

df_metrics_cp
# Out:
#                modelo  alpha  coverage  avg_set_size  pct_singletons  \
# 0   Árbol de decisión    0.1   1.00000      7.000000        0.000000
# 1  Red neuronal (MLP)    0.1   0.90358      3.396672        0.042293
# 2             XGBoost    0.1   0.90526      3.294374        0.034048
#
#    pct_multi
# 0   1.000000
# 1   0.957707
# 2   0.965952
